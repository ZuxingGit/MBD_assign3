# %% [markdown]
# # Task 1 Pattern Mining

# %% [markdown]
# ### Data Processing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, fpmax, fpgrowth
import warnings
warnings.filterwarnings('ignore')

# %%
#Download raw data
data = pd.read_csv('data/Groceries data train.csv')

# %%
data
# Out:
#        Member_number        Date  itemDescription  year  month  day  \
# 0               3021  30/01/2015      frankfurter  2015      1   30
# 1               1292  24/10/2015             pork  2015     10   24
# 2               4206   4/04/2014  root vegetables  2014      4    4
# 3               4369  25/08/2015           onions  2015      8   25
# 4               1522   1/07/2014          waffles  2014      7    1
# ...              ...         ...              ...   ...    ...  ...
# 26995           4206  14/01/2014       rolls/buns  2014      1   14
# 26996           1660  15/06/2014    domestic eggs  2014      6   15
# 26997           1595  10/05/2015       liver loaf  2015      5   10
# 26998           3231  31/03/2015          sausage  2015      3   31
# 26999           2550   7/12/2014      canned beer  2014     12    7
#
#        day_of_week
# 0                4
# 1                5
# 2                4
# 3                1
# 4                1
# ...            ...
# 26995            1
# 26996            6
# 26997            6
# 26998            1
# 26999            6
#
# [27000 rows x 7 columns]

# %%
data.columns
# Out:
# Index(['Member_number', 'Date', 'itemDescription', 'year', 'month', 'day',
#        'day_of_week'],
#       dtype='object')

# %%
# Group the data by 'Member_number' and 'Date', then aggregate the 'itemDescription' into lists
transactions_data = data.groupby(['Member_number'])['itemDescription'].apply(list).reset_index()

# Extract the list of transactions
transactions = transactions_data['itemDescription'].tolist()

sorted_transactions = [sorted(list(set(transaction))) for transaction in transactions]

transactions = sorted_transactions

transactions = [transaction for transaction in transactions if len(transaction) > 1]

# Display the first transaction as an example
transactions[0]
# Out:
# ['canned beer',
#  'misc. beverages',
#  'pastry',
#  'pickled vegetables',
#  'sausage',
#  'soda',
#  'yogurt']

# %%
print(type(transactions))
# Out:
# <class 'list'>

# %% [markdown]
# ### Frequent Patterns Mining by Apriori Algorithm

# %%
pip install apyori
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: apyori in c:\users\kevin c\appdata\roaming\python\python311\site-packages (1.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
from apyori import apriori
from mlxtend.frequent_patterns import association_rules
rules = apriori(transactions, min_support=0.002, min_confidence=0.8,min_lift=1, min_length=1)
Results = list(rules)
Results
# Out:
# [RelationRecord(items=frozenset({'whole milk', 'bottled water', 'canned vegetables'}), support=0.002425222312045271, ordered_statistics=[OrderedStatistic(items_base=frozenset({'bottled water', 'canned vegetables'}), items_add=frozenset({'whole milk'}), confidence=0.8181818181818182, lift=2.2760665121984465)]),
#  RelationRecord(items=frozenset({'spices', 'whole milk', 'bottled water'}), support=0.002425222312045271, ordered_statistics=[OrderedStatistic(items_base=frozenset({'spices', 'bottled water'}), items_add=frozenset({'whole milk'}), confidence=0.8181818181818182, lift=2.2760665121984465)]),
#  RelationRecord(items=frozenset({'whole milk', 'butter', 'dishes'}), support=0.002155753166262463, ordered_statistics=[OrderedStatistic(items_base=frozenset({'butter', 'dishes'}), items_add=frozenset({'whole milk'}), confidence=1.0, lift=2.7818590704647677)]),
#  RelationRecord(items=frozenset({'whole milk', 'canned fish', 'newspapers'}), support=0.002425222312045271, ordered_statistics=[OrderedStatistic(items_base=frozenset({'canned fish', 'newspapers'}), items_add=frozenset({'whole milk'}), confidence=0.8181818181818182, lift=2.2760665121984465)]),
#  RelationRecord(items=frozenset({'white bread', 'whole milk', 'napkins'}), support=0.004580975478307734, ordered_statistics=[OrderedStatistic(items_base=frozenset({'white bread', 'napkins'}), items_add=frozenset({'whole milk'}), confidence=0.8095238095238096, lift=2.2519811522810027)]),
#  RelationRecord(items=frozenset({'whole milk', 'soft cheese', 'pork'}), support=0.002425222312045271, ordered_statistics=[OrderedStatistic(items_base=frozenset({'soft cheese', 'pork'}), items_add=frozenset({'whole milk'}), confidence=0.8181818181818182, lift=2.2760665121984465)]),
#  RelationRecord(items=frozenset({'soda', 'frankfurter', 'rolls/buns', 'UHT-milk'}), support=0.002155753166262463, ordered_statistics=[OrderedStatistic(items_base=frozenset({'soda', 'frankfurter', 'UHT-milk'}), items_add=frozenset({'rolls/buns'}), confidence=1.0, lift=3.66699604743083)]),
#  RelationRecord(items=frozenset({'sausage', 'whole milk', 'rolls/buns', 'UHT-milk'}), support=0.0032336297493936943, ordered_statistics=[OrderedStatistic(items_base=frozenset({'sausage', 'rolls/buns', 'UHT-milk'}), items_add=frozenset({'whole milk'}), confidence=0.8571428571428571, lift=2.384450631826944)]),
#  RelationRecord(items=frozenset({'whole milk', 'shopping bags', 'canned beer', 'beef'}), support=0.002155753166262463, ordered_statistics=[OrderedStatistic(items_base=frozenset({'shopping bags', 'canned beer', 'beef'}), items_add=frozenset({'whole milk'}), confidence=1.0, lift=2.7818590704647677)]),
#  RelationRecord(items=frozenset({'whole milk', 'canned beer', 'tropical fruit', 'beef'}), support=0.002155753166262463, ordered_statistics=[OrderedStatistic(items_base=frozenset({'canned beer', 'tropical fruit', 'beef'}), items_add=frozenset({'whole milk'}), confidence=1.0, lift=2.7818590704647677)]),
#  RelationRecord(items=frozenset({'whole milk', 'citrus fruit', 'chocolate', 'beef'}), support=0.002155753166262463, ordered_statistics=[OrderedStatistic(items_base=frozenset({'citrus fruit', 'chocolate', 'beef'}), items_add=frozenset({'whole milk'}), confidence=0.8888888888888887, lift=2.4727636181909043)]),
#  RelationRecord(items=frozenset({'sausage', 'yogurt', 'other vegetables', 'beef'}), support=0.0035030988951765024, ordered_statistics=[OrderedStatistic(items_base=frozenset({'sausage', 'yogurt', 'beef'}), items_add=frozenset({'other vegetables'}), confidence=0.8125000000000001, lift=2.7764157458563536)]),
#  RelationRecord(items=frozenset({'other vegetables', 'whole milk', 'frankfurter', 'beverages'}), support=0.002155753166262463, ordered_statistics=[OrderedStatistic(items_base=frozenset({'other vegetables', 'frankfurter', 'beverages'}), items_add=frozenset({'whole milk'}), confidence=0.8888888888888887, lift=2.4727636181909043)]),
#  RelationRecord(items=frozenset({'yogurt', 'whole milk', 'margarine', 'beverages'}), support=0.002155753166262463, ordered_statistics=[OrderedStatistic(items_base=frozenset({'yogurt', 'margarine', 'beverages'}), items_add=frozenset({'whole milk'}), confidence=0.8888888888888887, lift=2.4727636181909043)]),
#  RelationRecord(items=frozenset({'sausage', 'whole milk', 'beverages', 'whipped/sour cream'}), support=0.002155753166262463, ordered_statistics=[OrderedStatistic(items_base=frozenset({'sausage', 'beverages', 'whipped/sour cream'}), items_add=frozenset({'whole milk'}), confidence=0.8888888888888887, lift=2.4727636181909043)]),
#  RelationRecord(items=frozenset({'pip fruit', 'whole milk', 'bottled beer', 'citrus fruit'}), support=0.002425222312045271, ordered_statistics=[OrderedStatistic(items_base=frozenset({'pip fruit', 'bottled beer', 'citrus fruit'}), items_add=frozenset({'whole milk'}), confidence=0.8181818181818182, lift=2.2760665121984465)]),
#  RelationRecord(items=frozenset({'whole milk', 'root vegetables', 'bottled beer', 'citrus fruit'}), support=0.002155753166262463, ordered_statistics=[OrderedStatistic(items_base=frozenset({'root vegetables', 'bottled beer', 'citrus fruit'}), items_add=frozenset({'whole milk'}), confidence=1.0, lift=2.7818590704647677)]),
#  RelationRecord(items=frozenset({'whole milk', 'bottled beer', 'rolls/buns', 'napkins'}), support=0.002425222312045271, ordered_statistics=[OrderedStatistic(items_base=frozenset({'bottled beer', 'rolls/buns', 'napkins'}), items_add=frozenset({'whole milk'}), confidence=0.8181818181818182, lift=2.2760665121984465)]),
#  RelationRecord(items=frozenset({'whole milk', 'bottled beer', 'other vegetables', 'onions'}), support=0.002425222312045271, ordered_statistics=[OrderedStatistic(items_base=frozenset({'bottled beer', 'other vegetables', 'onions'}), items_add=frozenset({'whole milk'}), confidence=0.9, lift=2.503673163418291)]),
#  RelationRecord(items=frozenset({'whipped/sour cream', 'whole milk', 'bottled beer', 'other vegetables'}), support=0.0035030988951765024, ordered_statistics=[OrderedStatistic(items_base=frozenset({'whipped/sour cream', 'bottled beer', 'other vegetables'}), items_add=frozenset({'whole milk'}), confidence=0.8125000000000001, lift=2.2602604947526244)]),
#  RelationRecord(items=frozenset({'white bread', 'whole milk', 'bottled beer', 'other vegetables'}), support=0.002425222312045271, ordered_statistics=[OrderedStatistic(items_base=frozenset({'white bread', 'bottled beer', 'other vegetables'}), items_add=frozenset({'whole milk'}), confidence=0.8181818181818182, lift=2.2760665121984465)]),
#  RelationRecord(items=frozenset({'specialty chocolate', 'root vegetables', 'bottled water', 'canned beer'}), support=0.002155753166262463, ordered_statistics=[OrderedStatistic(items_base=frozenset({'specialty chocolate', 'bottled water', 'canned beer'}), items_add=frozenset({'root vegetables'}), confidence=0.8888888888888887, lift=5.051556916794282)]),
#  RelationRecord(items=frozenset({'whole milk', 'bottled water', 'cream cheese ', 'fruit/vegetable juice'}), support=0.002155753166262463, ordered_statistics=[OrderedStatistic(items_base=frozenset({'bottled water', 'cream cheese ', 'fruit/vegetable juice'}), items_add=frozenset({'whole milk'}), confidence=1.0, lift=2.7818590704647677)]),
#  RelationRecord(items=frozenset({'yogurt', 'whole milk', 'bottled water', 'curd'}), support=0.004042037186742118, ordered_statistics=[OrderedStatistic(items_base=frozenset({'yogurt', 'bottled water', 'curd'}), items_add=frozenset({'whole milk'}), confidence=0.8333333333333334, lift=2.3182158920539733)]),
#  RelationRecord(items=frozenset({'yogurt', 'whole milk', 'margarine', 'bottled water'}), support=0.002425222312045271, ordered_statistics=[OrderedStatistic(items_base=frozenset({'yogurt', 'margarine', 'bottled water'}), items_add=frozenset({'whole milk'}), confidence=0.8181818181818182, lift=2.2760665121984465)]),
#  RelationRecord(items=frozenset({'whole milk', 'bottled water', 'meat', 'pastry'}), support=0.002155753166262463, ordered_statistics=[OrderedStatistic(items_base=frozenset({'bottled water', 'meat', 'pastry'}), items_add=frozenset({'whole milk'}), confidence=0.8888888888888887, lift=2.4727636181909043)]),
#  RelationRecord(items=frozenset({'pip fruit', 'whole milk', 'bottled water', 'yogurt'}), support=0.004042037186742118, ordered_statistics=[OrderedStatistic(items_base=frozenset({'pip fruit', 'yogurt', 'bottled water'}), items_add=frozenset({'whole milk'}), confidence=0.8333333333333334, lift=2.3182158920539733)]),
#  RelationRecord(items=frozenset({'whipped/sour cream', 'waffles', 'bottled water', 'tropical fruit'}), support=0.002155753166262463, ordered_statistics=[OrderedStatistic(items_base=frozenset({'whipped/sour cream', 'waffles', 'bottled water'}), items_add=frozenset({'tropical fruit'}), confidence=0.8888888888888887, lift=5.294810058855002)]),
#  RelationRecord(items=frozenset({'yogurt', 'whole milk', 'butter', 'brown bread'}), support=0.002425222312045271, ordered_statistics=[OrderedStatistic(items_base=frozenset({'yogurt', 'butter', 'brown bread'}), items_add=frozenset({'whole milk'}), confidence=0.9, lift=2.503673163418291)]),
#  RelationRecord(items=frozenset({'whole milk', 'canned beer', 'curd', 'brown bread'}), support=0.0026946914578280788, ordered_statistics=[OrderedStatistic(items_base=frozenset({'canned beer', 'curd', 'brown bread'}), items_add=frozenset({'whole milk'}), confidence=0.8333333333333334, lift=2.3182158920539733)]),
#  RelationRecord(items=frozenset({'whole milk', 'soda', 'curd', 'brown bread'}), support=0.0035030988951765024, ordered_statistics=[OrderedStatistic(items_base=frozenset({'soda', 'curd', 'brown bread'}), items_add=frozenset({'whole milk'}), confidence=0.9285714285714286, lift=2.583154851145856)]),
#  RelationRecord(items=frozenset({'whole milk', 'whipped/sour cream', 'tropical fruit', 'brown bread'}), support=0.0026946914578280788, ordered_statistics=[OrderedStatistic(items_base=frozenset({'whipped/sour cream', 'tropical fruit', 'brown bread'}), items_add=frozenset({'whole milk'}), confidence=0.8333333333333334, lift=2.3182158920539733)]),
#  RelationRecord(items=frozenset({'yogurt', 'whole milk', 'candy', 'pork'}), support=0.002155753166262463, ordered_statistics=[OrderedStatistic(items_base=frozenset({'whole milk', 'candy', 'pork'}), items_add=frozenset({'yogurt'}), confidence=0.8888888888888887, lift=4.175527426160337), OrderedStatistic(items_base=frozenset({'yogurt', 'candy', 'pork'}), items_add=frozenset({'whole milk'}), confidence=0.8888888888888887, lift=2.4727636181909043)]),
#  RelationRecord(items=frozenset({'whole milk', 'canned beer', 'citrus fruit', 'sugar'}), support=0.002155753166262463, ordered_statistics=[OrderedStatistic(items_base=frozenset({'canned beer', 'citrus fruit', 'sugar'}), items_add=frozenset({'whole milk'}), confidence=1.0, lift=2.7818590704647677)]),
#  RelationRecord(items=frozenset({'whole milk', 'soda', 'canned beer', 'curd'}), support=0.0029641606036108865, ordered_statistics=[OrderedStatistic(items_base=frozenset({'soda', 'canned beer', 'curd'}), items_add=frozenset({'whole milk'}), confidence=0.8461538461538461, lift=2.3538807519317264)]),
#  RelationRecord(items=frozenset({'shopping bags', 'soda', 'canned beer', 'domestic eggs'}), support=0.002425222312045271, ordered_statistics=[OrderedStatistic(items_base=frozenset({'shopping bags', 'canned beer', 'domestic eggs'}), items_add=frozenset({'soda'}), confidence=0.8181818181818182, lift=3.362428269405014)]),
#  RelationRecord(items=frozenset({'whole milk', 'shopping bags', 'canned beer', 'fruit/vegetable juice'}), support=0.002425222312045271, ordered_statistics=[OrderedStatistic(items_base=frozenset({'shopping bags', 'canned beer', 'fruit/vegetable juice'}), items_add=frozenset({'whole milk'}), confidence=0.8181818181818182, lift=2.2760665121984465)]),
#  RelationRecord(items=frozenset({'sausage', 'whole milk', 'canned beer', 'whipped/sour cream'}), support=0.0035030988951765024, ordered_statistics=[OrderedStatistic(items_base=frozenset({'sausage', 'canned beer', 'whipped/sour cream'}), items_add=frozenset({'whole milk'}), confidence=0.9285714285714286, lift=2.583154851145856)]),
#  RelationRecord(items=frozenset({'coffee', 'whole milk', 'chewing gum', 'yogurt'}), support=0.002155753166262463, ordered_statistics=[OrderedStatistic(items_base=frozenset({'coffee', 'yogurt', 'chewing gum'}), items_add=frozenset({'whole milk'}), confidence=0.8888888888888887, lift=2.4727636181909043)]),
#  RelationRecord(items=frozenset({'whole milk', 'shopping bags', 'citrus fruit', 'chicken'}), support=0.002425222312045271, ordered_statistics=[OrderedStatistic(items_base=frozenset({'shopping bags', 'citrus fruit', 'chicken'}), items_add=frozenset({'whole milk'}), confidence=0.9, lift=2.503673163418291)]),
#  RelationRecord(items=frozenset({'coffee', 'whole milk', 'other vegetables', 'chocolate'}), support=0.0026946914578280788, ordered_statistics=[OrderedStatistic(items_base=frozenset({'coffee', 'other vegetables', 'chocolate'}), items_add=frozenset({'whole milk'}), confidence=0.8333333333333334, lift=2.3182158920539733)]),
#  RelationRecord(items=frozenset({'whipped/sour cream', 'yogurt', 'other vegetables', 'chocolate'}), support=0.002425222312045271, ordered_statistics=[OrderedStatistic(items_base=frozenset({'yogurt', 'whipped/sour cream', 'chocolate'}), items_add=frozenset({'other vegetables'}), confidence=0.8181818181818182, lift=2.7958312405826216)]),
#  RelationRecord(items=frozenset({'yogurt', 'whole milk', 'chocolate', 'tropical fruit'}), support=0.002155753166262463, ordered_statistics=[OrderedStatistic(items_base=frozenset({'yogurt', 'chocolate', 'tropical fruit'}), items_add=frozenset({'whole milk'}), confidence=0.8888888888888887, lift=2.4727636181909043)]),
#  RelationRecord(items=frozenset({'yogurt', 'whole milk', 'whipped/sour cream', 'chocolate'}), support=0.002425222312045271, ordered_statistics=[OrderedStatistic(items_base=frozenset({'yogurt', 'whipped/sour cream', 'chocolate'}), items_add=frozenset({'whole milk'}), confidence=0.8181818181818182, lift=2.2760665121984465)]),
#  RelationRecord(items=frozenset({'whole milk', 'frozen meals', 'citrus fruit', 'rolls/buns'}), support=0.0026946914578280788, ordered_statistics=[OrderedStatistic(items_base=frozenset({'whole milk', 'frozen meals', 'citrus fruit'}), items_add=frozenset({'rolls/buns'}), confidence=0.8333333333333334, lift=3.055830039525692)]),
#  RelationRecord(items=frozenset({'pip fruit', 'whole milk', 'citrus fruit', 'hamburger meat'}), support=0.002155753166262463, ordered_statistics=[OrderedStatistic(items_base=frozenset({'pip fruit', 'citrus fruit', 'hamburger meat'}), items_add=frozenset({'whole milk'}), confidence=0.8888888888888887, lift=2.4727636181909043)]),
#  RelationRecord(items=frozenset({'whole milk', 'margarine', 'citrus fruit', 'pastry'}), support=0.002425222312045271, ordered_statistics=[OrderedStatistic(items_base=frozenset({'margarine', 'citrus fruit', 'pastry'}), items_add=frozenset({'whole milk'}), confidence=0.9, lift=2.503673163418291)]),
#  RelationRecord(items=frozenset({'whole milk', 'shopping bags', 'citrus fruit', 'napkins'}), support=0.002425222312045271, ordered_statistics=[OrderedStatistic(items_base=frozenset({'shopping bags', 'citrus fruit', 'napkins'}), items_add=frozenset({'whole milk'}), confidence=0.9, lift=2.503673163418291)]),
#  RelationRecord(items=frozenset({'other vegetables', 'whole milk', 'citrus fruit', 'specialty chocolate'}), support=0.004042037186742118, ordered_statistics=[OrderedStatistic(items_base=frozenset({'specialty chocolate', 'whole milk', 'citrus fruit'}), items_add=frozenset({'other vegetables'}), confidence=0.8823529411764707, lift=3.0151121221969452)]),
#  RelationRecord(items=frozenset({'sausage', 'whole milk', 'citrus fruit', 'whipped/sour cream'}), support=0.0029641606036108865, ordered_statistics=[OrderedStatistic(items_base=frozenset({'sausage', 'citrus fruit', 'whipped/sour cream'}), items_add=frozenset({'whole milk'}), confidence=0.8461538461538461, lift=2.3538807519317264)]),
#  RelationRecord(items=frozenset({'whipped/sour cream', 'whole milk', 'citrus fruit', 'yogurt'}), support=0.002425222312045271, ordered_statistics=[OrderedStatistic(items_base=frozenset({'whipped/sour cream', 'yogurt', 'citrus fruit'}), items_add=frozenset({'whole milk'}), confidence=0.8181818181818182, lift=2.2760665121984465)]),
#  RelationRecord(items=frozenset({'coffee', 'shopping bags', 'soda', 'other vegetables'}), support=0.0032336297493936943, ordered_statistics=[OrderedStatistic(items_base=frozenset({'coffee', 'shopping bags', 'soda'}), items_add=frozenset({'other vegetables'}), confidence=0.8571428571428571, lift=2.9289660615627464)]),
#  RelationRecord(items=frozenset({'coffee', 'whole milk', 'yogurt', 'pip fruit'}), support=0.002425222312045271, ordered_statistics=[OrderedStatistic(items_base=frozenset({'coffee', 'yogurt', 'pip fruit'}), items_add=frozenset({'whole milk'}), confidence=0.8181818181818182, lift=2.2760665121984465)]),
#  RelationRecord(items=frozenset({'whole milk', 'other vegetables', 'cream cheese ', 'pork'}), support=0.002425222312045271, ordered_statistics=[OrderedStatistic(items_base=frozenset({'other vegetables', 'cream cheese ', 'pork'}), items_add=frozenset({'whole milk'}), confidence=1.0, lift=2.7818590704647677)]),
#  RelationRecord(items=frozenset({'sausage', 'whole milk', 'domestic eggs', 'curd'}), support=0.0026946914578280788, ordered_statistics=[OrderedStatistic(items_base=frozenset({'sausage', 'domestic eggs', 'curd'}), items_add=frozenset({'whole milk'}), confidence=0.9090909090909092, lift=2.5289627913316073)]),
#  RelationRecord(items=frozenset({'whole milk', 'soda', 'domestic eggs', 'curd'}), support=0.002155753166262463, ordered_statistics=[OrderedStatistic(items_base=frozenset({'soda', 'domestic eggs', 'curd'}), items_add=frozenset({'whole milk'}), confidence=0.8888888888888887, lift=2.4727636181909043)]),
#  RelationRecord(items=frozenset({'whole milk', 'newspapers', 'domestic eggs', 'tropical fruit'}), support=0.002155753166262463, ordered_statistics=[OrderedStatistic(items_base=frozenset({'newspapers', 'domestic eggs', 'tropical fruit'}), items_add=frozenset({'whole milk'}), confidence=0.8888888888888887, lift=2.4727636181909043)]),
#  RelationRecord(items=frozenset({'whole milk', 'domestic eggs', 'tropical fruit', 'pork'}), support=0.002155753166262463, ordered_statistics=[OrderedStatistic(items_base=frozenset({'domestic eggs', 'tropical fruit', 'pork'}), items_add=frozenset({'whole milk'}), confidence=0.8888888888888887, lift=2.4727636181909043)]),
#  RelationRecord(items=frozenset({'yogurt', 'whole milk', 'domestic eggs', 'pork'}), support=0.002425222312045271, ordered_statistics=[OrderedStatistic(items_base=frozenset({'yogurt', 'domestic eggs', 'pork'}), items_add=frozenset({'whole milk'}), confidence=0.8181818181818182, lift=2.2760665121984465)]),
#  RelationRecord(items=frozenset({'sausage', 'soda', 'frankfurter', 'pastry'}), support=0.002425222312045271, ordered_statistics=[OrderedStatistic(items_base=frozenset({'sausage', 'frankfurter', 'pastry'}), items_add=frozenset({'soda'}), confidence=0.8181818181818182, lift=3.362428269405014)]),
#  RelationRecord(items=frozenset({'other vegetables', 'whole milk', 'frozen meals', 'frozen vegetables'}), support=0.002155753166262463, ordered_statistics=[OrderedStatistic(items_base=frozenset({'whole milk', 'frozen meals', 'frozen vegetables'}), items_add=frozenset({'other vegetables'}), confidence=0.8888888888888887, lift=3.03744628606507)]),
#  RelationRecord(items=frozenset({'yogurt', 'whole milk', 'frozen meals', 'tropical fruit'}), support=0.002155753166262463, ordered_statistics=[OrderedStatistic(items_base=frozenset({'yogurt', 'frozen meals', 'tropical fruit'}), items_add=frozenset({'whole milk'}), confidence=0.8888888888888887, lift=2.4727636181909043)]),
#  RelationRecord(items=frozenset({'yogurt', 'whole milk', 'root vegetables', 'ham'}), support=0.0026946914578280788, ordered_statistics=[OrderedStatistic(items_base=frozenset({'yogurt', 'root vegetables', 'ham'}), items_add=frozenset({'whole milk'}), confidence=0.8333333333333334, lift=2.3182158920539733)]),
#  RelationRecord(items=frozenset({'pip fruit', 'whole milk', 'other vegetables', 'hamburger meat'}), support=0.002425222312045271, ordered_statistics=[OrderedStatistic(items_base=frozenset({'pip fruit', 'other vegetables', 'hamburger meat'}), items_add=frozenset({'whole milk'}), confidence=0.8181818181818182, lift=2.2760665121984465)]),
#  RelationRecord(items=frozenset({'yogurt', 'whole milk', 'other vegetables', 'herbs'}), support=0.002425222312045271, ordered_statistics=[OrderedStatistic(items_base=frozenset({'yogurt', 'other vegetables', 'herbs'}), items_add=frozenset({'whole milk'}), confidence=0.8181818181818182, lift=2.2760665121984465)]),
#  RelationRecord(items=frozenset({'sausage', 'whole milk', 'ice cream', 'rolls/buns'}), support=0.002155753166262463, ordered_statistics=[OrderedStatistic(items_base=frozenset({'sausage', 'ice cream', 'rolls/buns'}), items_add=frozenset({'whole milk'}), confidence=0.8888888888888887, lift=2.4727636181909043)]),
#  RelationRecord(items=frozenset({'whipped/sour cream', 'whole milk', 'other vegetables', 'meat'}), support=0.002155753166262463, ordered_statistics=[OrderedStatistic(items_base=frozenset({'whipped/sour cream', 'other vegetables', 'meat'}), items_add=frozenset({'whole milk'}), confidence=0.8888888888888887, lift=2.4727636181909043)]),
#  RelationRecord(items=frozenset({'whole milk', 'soda', 'pastry', 'meat'}), support=0.002425222312045271, ordered_statistics=[OrderedStatistic(items_base=frozenset({'soda', 'pastry', 'meat'}), items_add=frozenset({'whole milk'}), confidence=0.8181818181818182, lift=2.2760665121984465)]),
#  RelationRecord(items=frozenset({'whole milk', 'misc. beverages', 'yogurt', 'pastry'}), support=0.002155753166262463, ordered_statistics=[OrderedStatistic(items_base=frozenset({'yogurt', 'misc. beverages', 'pastry'}), items_add=frozenset({'whole milk'}), confidence=0.8888888888888887, lift=2.4727636181909043)]),
#  RelationRecord(items=frozenset({'whole milk', 'root vegetables', 'newspapers', 'tropical fruit'}), support=0.0026946914578280788, ordered_statistics=[OrderedStatistic(items_base=frozenset({'root vegetables', 'newspapers', 'tropical fruit'}), items_add=frozenset({'whole milk'}), confidence=0.8333333333333334, lift=2.3182158920539733)]),
#  RelationRecord(items=frozenset({'sausage', 'shopping bags', 'newspapers', 'whole milk'}), support=0.002425222312045271, ordered_statistics=[OrderedStatistic(items_base=frozenset({'sausage', 'shopping bags', 'newspapers'}), items_add=frozenset({'whole milk'}), confidence=0.8181818181818182, lift=2.2760665121984465)]),
#  RelationRecord(items=frozenset({'sausage', 'whole milk', 'newspapers', 'whipped/sour cream'}), support=0.004042037186742118, ordered_statistics=[OrderedStatistic(items_base=frozenset({'sausage', 'newspapers', 'whipped/sour cream'}), items_add=frozenset({'whole milk'}), confidence=0.8333333333333334, lift=2.3182158920539733)]),
#  RelationRecord(items=frozenset({'yogurt', 'shopping bags', 'other vegetables', 'pastry'}), support=0.002425222312045271, ordered_statistics=[OrderedStatistic(items_base=frozenset({'yogurt', 'shopping bags', 'pastry'}), items_add=frozenset({'other vegetables'}), confidence=0.8181818181818182, lift=2.7958312405826216)]),
#  RelationRecord(items=frozenset({'whipped/sour cream', 'yogurt', 'other vegetables', 'pastry'}), support=0.0026946914578280788, ordered_statistics=[OrderedStatistic(items_base=frozenset({'yogurt', 'whipped/sour cream', 'pastry'}), items_add=frozenset({'other vegetables'}), confidence=0.8333333333333334, lift=2.8476058931860035)]),
#  RelationRecord(items=frozenset({'yogurt', 'whole milk', 'whipped/sour cream', 'pastry'}), support=0.0026946914578280788, ordered_statistics=[OrderedStatistic(items_base=frozenset({'yogurt', 'whipped/sour cream', 'pastry'}), items_add=frozenset({'whole milk'}), confidence=0.8333333333333334, lift=2.3182158920539733)]),
#  RelationRecord(items=frozenset({'pip fruit', 'whole milk', 'tropical fruit', 'pork'}), support=0.0026946914578280788, ordered_statistics=[OrderedStatistic(items_base=frozenset({'pip fruit', 'tropical fruit', 'pork'}), items_add=frozenset({'whole milk'}), confidence=0.8333333333333334, lift=2.3182158920539733)]),
#  RelationRecord(items=frozenset({'yogurt', 'whole milk', 'tropical fruit', 'pork'}), support=0.0029641606036108865, ordered_statistics=[OrderedStatistic(items_base=frozenset({'yogurt', 'tropical fruit', 'pork'}), items_add=frozenset({'whole milk'}), confidence=0.9166666666666667, lift=2.5500374812593707)]),
#  RelationRecord(items=frozenset({'berries', 'other vegetables', 'yogurt', 'tropical fruit', 'whole milk'}), support=0.002425222312045271, ordered_statistics=[OrderedStatistic(items_base=frozenset({'whole milk', 'berries', 'other vegetables', 'tropical fruit'}), items_add=frozenset({'yogurt'}), confidence=0.8181818181818182, lift=3.843383199079402), OrderedStatistic(items_base=frozenset({'yogurt', 'berries', 'other vegetables', 'tropical fruit'}), items_add=frozenset({'whole milk'}), confidence=0.9, lift=2.503673163418291), OrderedStatistic(items_base=frozenset({'whole milk', 'berries', 'yogurt', 'tropical fruit'}), items_add=frozenset({'other vegetables'}), confidence=0.8181818181818182, lift=2.7958312405826216)]),
#  RelationRecord(items=frozenset({'bottled water', 'coffee', 'other vegetables', 'whole milk', 'soda'}), support=0.002425222312045271, ordered_statistics=[OrderedStatistic(items_base=frozenset({'coffee', 'other vegetables', 'soda', 'bottled water'}), items_add=frozenset({'whole milk'}), confidence=0.9, lift=2.503673163418291)]),
#  RelationRecord(items=frozenset({'bottled water', 'curd', 'other vegetables', 'yogurt', 'whole milk'}), support=0.002155753166262463, ordered_statistics=[OrderedStatistic(items_base=frozenset({'other vegetables', 'yogurt', 'bottled water', 'curd'}), items_add=frozenset({'whole milk'}), confidence=1.0, lift=2.7818590704647677)]),
#  RelationRecord(items=frozenset({'bottled water', 'curd', 'yogurt', 'whole milk', 'soda'}), support=0.002425222312045271, ordered_statistics=[OrderedStatistic(items_base=frozenset({'yogurt', 'soda', 'bottled water', 'curd'}), items_add=frozenset({'whole milk'}), confidence=0.9, lift=2.503673163418291)]),
#  RelationRecord(items=frozenset({'bottled water', 'pip fruit', 'other vegetables', 'yogurt', 'whole milk'}), support=0.0026946914578280788, ordered_statistics=[OrderedStatistic(items_base=frozenset({'other vegetables', 'yogurt', 'bottled water', 'pip fruit'}), items_add=frozenset({'whole milk'}), confidence=0.9090909090909092, lift=2.5289627913316073)]),
#  RelationRecord(items=frozenset({'bottled water', 'rolls/buns', 'whole milk', 'soda', 'whipped/sour cream'}), support=0.002425222312045271, ordered_statistics=[OrderedStatistic(items_base=frozenset({'whipped/sour cream', 'soda', 'bottled water', 'rolls/buns'}), items_add=frozenset({'whole milk'}), confidence=0.8181818181818182, lift=2.2760665121984465)]),
#  RelationRecord(items=frozenset({'rolls/buns', 'shopping bags', 'whole milk', 'soda', 'canned beer'}), support=0.0026946914578280788, ordered_statistics=[OrderedStatistic(items_base=frozenset({'shopping bags', 'soda', 'canned beer', 'rolls/buns'}), items_add=frozenset({'whole milk'}), confidence=0.8333333333333334, lift=2.3182158920539733)]),
#  RelationRecord(items=frozenset({'rolls/buns', 'frozen vegetables', 'other vegetables', 'yogurt', 'sausage'}), support=0.002425222312045271, ordered_statistics=[OrderedStatistic(items_base=frozenset({'sausage', 'yogurt', 'other vegetables', 'frozen vegetables'}), items_add=frozenset({'rolls/buns'}), confidence=0.9, lift=3.3002964426877472)]),
#  RelationRecord(items=frozenset({'rolls/buns', 'root vegetables', 'sausage', 'whole milk', 'soda'}), support=0.0026946914578280788, ordered_statistics=[OrderedStatistic(items_base=frozenset({'sausage', 'soda', 'root vegetables', 'rolls/buns'}), items_add=frozenset({'whole milk'}), confidence=0.8333333333333334, lift=2.3182158920539733)])]

# %%
df_results = pd.DataFrame(Results)
df_results
# Out:
#                                                 items   support  \
# 0      (whole milk, bottled water, canned vegetables)  0.002425
# 1                 (spices, whole milk, bottled water)  0.002425
# 2                        (whole milk, butter, dishes)  0.002156
# 3               (whole milk, canned fish, newspapers)  0.002425
# 4                  (white bread, whole milk, napkins)  0.004581
# ..                                                ...       ...
# 81  (bottled water, pip fruit, other vegetables, y...  0.002695
# 82  (bottled water, rolls/buns, whole milk, soda, ...  0.002425
# 83  (rolls/buns, shopping bags, whole milk, soda, ...  0.002695
# 84  (rolls/buns, frozen vegetables, other vegetabl...  0.002425
# 85  (rolls/buns, root vegetables, sausage, whole m...  0.002695
#
#                                    ordered_statistics
# 0   [((bottled water, canned vegetables), (whole m...
# 1   [((spices, bottled water), (whole milk), 0.818...
# 2   [((butter, dishes), (whole milk), 1.0, 2.78185...
# 3   [((canned fish, newspapers), (whole milk), 0.8...
# 4   [((white bread, napkins), (whole milk), 0.8095...
# ..                                                ...
# 81  [((other vegetables, yogurt, bottled water, pi...
# 82  [((whipped/sour cream, soda, bottled water, ro...
# 83  [((shopping bags, soda, canned beer, rolls/bun...
# 84  [((sausage, yogurt, other vegetables, frozen v...
# 85  [((sausage, soda, root vegetables, rolls/buns)...
#
# [86 rows x 3 columns]

# %%
# keep support in a separate data
support = df_results.support

# %%
#all four empty list which will contain lhs, rhs, confidance and lift respectively.
first_values = []
second_values = []
third_values = []
fourth_value = []

# loop number of rows time and append 1 by 1 value in a separate list
# first and second element was frozenset which need to be converted in list
for i in range(df_results.shape[0]):
    single_list = df_results['ordered_statistics'][i][0]
    first_values.append(list(single_list[0]))
    second_values.append(list(single_list[1]))
    third_values.append(single_list[2])
    fourth_value.append(single_list[3])

# %%
# convert all four list into dataframe for further operation
lhs = pd.DataFrame(first_values)
rhs = pd.DataFrame(second_values)

confidance=pd.DataFrame(third_values,columns=['Confidance'])

lift=pd.DataFrame(fourth_value,columns=['lift'])

# %%
# concat all list together in a single dataframe
df_final = pd.concat([lhs,rhs,support,confidance,lift], axis=1)
df_final
df_final.fillna(value=' ', inplace=True)
df_final.head()
# Out:
#                0                  1  2  3           0   support  Confidance  \
# 0  bottled water  canned vegetables        whole milk  0.002425    0.818182
# 1         spices      bottled water        whole milk  0.002425    0.818182
# 2         butter             dishes        whole milk  0.002156    1.000000
# 3    canned fish         newspapers        whole milk  0.002425    0.818182
# 4    white bread            napkins        whole milk  0.004581    0.809524
#
#        lift
# 0  2.276067
# 1  2.276067
# 2  2.781859
# 3  2.276067
# 4  2.251981

# %%
#set column name
df_final.columns = ['lhs',1,2,3,'rhs','support','confidance','lift']
df_final.head()
# Out:
#              lhs                  1  2  3         rhs   support  confidance  \
# 0  bottled water  canned vegetables        whole milk  0.002425    0.818182
# 1         spices      bottled water        whole milk  0.002425    0.818182
# 2         butter             dishes        whole milk  0.002156    1.000000
# 3    canned fish         newspapers        whole milk  0.002425    0.818182
# 4    white bread            napkins        whole milk  0.004581    0.809524
#
#        lift
# 0  2.276067
# 1  2.276067
# 2  2.781859
# 3  2.276067
# 4  2.251981

# %%
# add all three column to lhs itemset only
df_final['lhs'] = df_final['lhs'] + str(", ")  + df_final[1] + str(", ") + df_final[2] + df_final[3]

df_final['rhs'] = df_final['rhs'] + str(", ")

# %%
df_final.drop(columns=[1,2,3],inplace=True)

# %%
df_final.sort_values('lift', ascending=False).head(10)
# Out:
#                                                   lhs                 rhs  \
# 27        whipped/sour cream, waffles, bottled water     tropical fruit,
# 21   specialty chocolate, bottled water, canned beer    root vegetables,
# 32                           whole milk, candy, pork             yogurt,
# 77  whole milk, berries, other vegetablestropical ...            yogurt,
# 6                        soda, frankfurter, UHT-milk         rolls/buns,
# 59                      sausage, frankfurter, pastry               soda,
# 35         shopping bags, canned beer, domestic eggs               soda,
# 84  sausage, yogurt, other vegetablesfrozen vegeta...        rolls/buns,
# 44            whole milk, frozen meals, citrus fruit         rolls/buns,
# 60       whole milk, frozen meals, frozen vegetables   other vegetables,
#
#      support  confidance      lift
# 27  0.002156    0.888889  5.294810
# 21  0.002156    0.888889  5.051557
# 32  0.002156    0.888889  4.175527
# 77  0.002425    0.818182  3.843383
# 6   0.002156    1.000000  3.666996
# 59  0.002425    0.818182  3.362428
# 35  0.002425    0.818182  3.362428
# 84  0.002425    0.900000  3.300296
# 44  0.002695    0.833333  3.055830
# 60  0.002156    0.888889  3.037446

# %% [markdown]
# Note: The code above applies the Apriori algorithm for pattern mining on all transactions and stores the results in a list named Results. These results can be visualized in a tabular format for better analysis and interpretation of the association rules.

# %% [markdown]
# ### Prediction Functions Based on Discovered Patterns (Ready for Import to Task 2)

# %%
te = TransactionEncoder()
te_ary = te.fit(transactions).transform(transactions)
df = pd.DataFrame(te_ary, columns=te.columns_)

# %%
df
# Out:
#       Instant food products  UHT-milk  abrasive cleaner  artif. sweetener  \
# 0                     False     False             False             False
# 1                     False     False             False             False
# 2                     False     False             False             False
# 3                     False     False             False             False
# 4                     False     False             False             False
# ...                     ...       ...               ...               ...
# 3706                  False     False             False             False
# 3707                  False     False             False             False
# 3708                  False     False             False             False
# 3709                  False     False             False             False
# 3710                  False     False             False             False
#
#       baby cosmetics   bags  baking powder  bathroom cleaner   beef  berries  \
# 0              False  False          False             False  False    False
# 1              False  False          False             False   True    False
# 2              False  False          False             False  False    False
# 3              False  False          False             False  False    False
# 4              False  False          False             False  False    False
# ...              ...    ...            ...               ...    ...      ...
# 3706           False  False          False             False  False    False
# 3707           False  False          False             False  False    False
# 3708           False  False          False             False  False    False
# 3709           False  False          False             False  False     True
# 3710           False  False          False             False  False    False
#
#       ...  turkey  vinegar  waffles  whipped/sour cream  whisky  white bread  \
# 0     ...   False    False    False               False   False        False
# 1     ...   False    False    False                True   False         True
# 2     ...   False    False    False               False   False        False
# 3     ...   False    False    False               False   False        False
# 4     ...   False    False    False               False   False        False
# ...   ...     ...      ...      ...                 ...     ...          ...
# 3706  ...   False    False    False               False   False        False
# 3707  ...   False    False    False               False   False        False
# 3708  ...   False    False    False               False   False        False
# 3709  ...   False    False    False               False   False        False
# 3710  ...   False    False    False               False   False        False
#
#       white wine  whole milk  yogurt  zwieback
# 0          False       False    True     False
# 1          False        True   False     False
# 2          False        True   False     False
# 3          False       False   False     False
# 4          False        True   False     False
# ...          ...         ...     ...       ...
# 3706       False       False   False     False
# 3707        True       False   False     False
# 3708       False       False   False     False
# 3709       False       False   False     False
# 3710       False       False   False     False
#
# [3711 rows x 167 columns]

# %%
from mlxtend.frequent_patterns import apriori, association_rules
import pandas as pd

frequent_itemsets = apriori(df, min_support=0.002, use_colnames=True)

rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.4)
rules
# Out:
#                                             antecedents         consequents  \
# 0                               (Instant food products)   (root vegetables)
# 1                               (Instant food products)              (soda)
# 2                               (Instant food products)        (whole milk)
# 3                                            (UHT-milk)        (whole milk)
# 4                                    (artif. sweetener)  (other vegetables)
# ...                                                 ...                 ...
# 5438       (sausage, whole milk, soda, root vegetables)            (yogurt)
# 5439  (sausage, yogurt, whipped/sour cream, whole milk)              (soda)
# 5440        (sausage, yogurt, soda, whipped/sour cream)        (whole milk)
# 5441     (whole milk, yogurt, soda, whipped/sour cream)           (sausage)
# 5442    (sausage, whole milk, soda, whipped/sour cream)            (yogurt)
#
#       antecedent support  consequent support   support  confidence      lift  \
# 0               0.011318            0.175963  0.004581    0.404762  2.300263
# 1               0.011318            0.243331  0.004850    0.428571  1.761272
# 2               0.011318            0.359472  0.004581    0.404762  1.125991
# 3               0.054702            0.359472  0.023713    0.433498  1.205929
# 4               0.005659            0.292643  0.002425    0.428571  1.464483
# ...                  ...                 ...       ...         ...       ...
# 5438            0.004850            0.212881  0.002156    0.444444  2.087764
# 5439            0.005389            0.243331  0.002695    0.500000  2.054817
# 5440            0.003503            0.359472  0.002695    0.769231  2.139892
# 5441            0.005389            0.153867  0.002695    0.500000  3.249562
# 5442            0.005389            0.212881  0.002695    0.500000  2.348734
#
#       leverage  conviction  zhangs_metric
# 0     0.002589    1.384382       0.571738
# 1     0.002097    1.324171       0.437176
# 2     0.000513    1.076087       0.113174
# 3     0.004049    1.130671       0.180646
# 4     0.000769    1.237874       0.318970
# ...        ...         ...            ...
# 5438  0.001123    1.416815       0.523558
# 5439  0.001383    1.513339       0.516120
# 5440  0.001435    2.775622       0.534559
# 5441  0.001865    1.692266       0.696017
# 5442  0.001547    1.574239       0.577350
#
# [5443 rows x 10 columns]

# %%
# frequent_itemsets = fpgrowth(df, min_support=0.002, use_colnames=True)
# frequent_itemsets

# from mlxtend.frequent_patterns import association_rules
# rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.4)
# rules

# %%
def predict_items(purchased_items):
    # create a list to store the predicted items
    predicted_items = []
    
    # iterate over the top rules
    for index, row in rules.iterrows():
        # get the items in the antecedent and consequent of the rule
        antecedent = row["antecedents"]
        consequent = row["consequents"]
        
        # check if all the items in the antecedent are in the purchased items
        if antecedent.issubset(purchased_items):
            # add the items in the consequent to the predicted items
            for item in consequent:
                if item not in purchased_items and item not in predicted_items:
                    predicted_items.append(item)
    
    # return the list of predicted items
    return predicted_items

# %%
# make a prediction for a sample set of purchased items
purchased_items = {"yogurt", "soda"}
predicted_items = predict_items(purchased_items)

# print the predicted items to the console
print(predicted_items)
# Out:
# ['whole milk']

# %%
# make a prediction for a sample set of purchased items
purchased_items = {'canned beer',
 'misc. beverages',
 'pastry',
 'pickled vegetables',
 'sausage',
 'soda',
 'yogurt'}
predicted_items = predict_items(purchased_items)

# print the predicted items to the console
print(predicted_items)
# Out:
# ['whole milk', 'rolls/buns', 'other vegetables', 'pip fruit']

# %% [markdown]
# Note: The code above prepares prediction functions based on discovered patterns, which can be used for Task 2. It includes implementations of both the Apriori and FP-Growth algorithms for pattern mining (Apriori is the default algorithm, and the part of the code for FP-Growth is currently commented out with a hash symbol). These functions can be imported and utilized as needed.
